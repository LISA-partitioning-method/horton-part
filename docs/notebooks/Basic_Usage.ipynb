# %% [markdown]
# # Basic Usage
#
# This example on CO illustates all the features of using horton-part package.
#
# The format checkpoint file wavefunction is included in "docs/notebooks/data/co.fchk" and is
# read using the [IOData](https://github.com/theochem/iodata) package.

# %%
import numpy as np
from iodata import load_one
from gbasis.evals.eval import evaluate_basis
from gbasis.wrappers import from_iodata
from grid import ExpRTransform, UniformInteger, BeckeWeights, MolGrid


def prepare_grid_and_dens():
    """Prepare molecular grid and density."""
    mol = load_one('data/co.fchk')

    # Specify the integration grid
    rtf = ExpRTransform(5e-4, 2e1, 120 - 1)
    uniform_grid = UniformInteger(120)
    rgrid = rtf.transform_1d_grid(uniform_grid)
    becke = BeckeWeights()
    grid = MolGrid.from_preset(
        mol.atnums, mol.atcoords, rgrid, "fine", becke, rotate=False, store=True
    )

    # Get the spin-summed density matrix
    one_rdm = mol.one_rdms.get("post_scf", mol.one_rdms.get("scf"))
    basis, coord_types = from_iodata(mol)
    basis_grid = evaluate_basis(basis, grid.points, coord_type=coord_types)
    rho = np.einsum("ab,bp,ap->p", one_rdm, basis_grid, basis_grid, optimize=True)
    nelec = grid.integrate(rho)
    print(f"The number of electrons: {nelec}")
    print(f"Coordinates of the atoms \n {mol.atcoords}")
    print(f"Atomic numbers of the atom \n {mol.atnums}")
    return mol, grid, rho

# %% [markdown]
# ## ISA method

# %%
from horton_part import ISAWPart

def main_isa():
    mol, grid, rho = prepare_grid_and_dens()
    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
    }

    part = ISAWPart(**kwargs)
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_isa()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.19844372 -0.19856088]
# cartesian multipoles:
# [[ 1.98443716e-01  1.10081030e-16  1.20583349e-15 -3.03946476e-01
#   -3.87895465e+00 -1.36477346e-15  8.31544710e-16 -3.87895465e+00
#   -7.78959991e-16 -4.77393559e+00  2.85518570e-15  1.63734207e-15
#   -2.35286418e-01  1.53083221e-15 -5.84653386e-16  1.63575629e-15
#    1.09603282e-14 -2.35286418e-01  1.72518206e-15 -1.16023931e+00]
#  [-1.98560882e-01  1.35583310e-16  7.56012771e-17 -1.28707660e-02
#   -3.74640413e+00 -2.00442265e-15  4.07249533e-16 -3.74640413e+00
#    1.44724371e-16 -3.83832726e+00 -3.85328999e-16  8.77128408e-16
#    1.15252270e-01  1.25219095e-16 -1.47004090e-15 -1.81948807e-15
#    6.03438572e-15  1.15252270e-01  1.62450907e-15  1.36465646e-01]]

# %% [markdown]
# ## MBIS method

# %%
from horton_part import MBISWPart

def main_mbis():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
    }

    part = MBISWPart(**kwargs)
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_mbis()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# /Users/yingxing/Projects/horton-part/src/horton_part/utils.py:541: UserWarning: The sum of pro-atom parameters is not equal to atomic population
#   warnings.warn(
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.24139112 -0.24124096]
# cartesian multipoles:
# [[ 2.41391119e-01  4.90131889e-17  1.35173606e-15 -3.24210581e-01
#   -3.82813189e+00 -1.26087591e-15  1.17158854e-15 -3.82813189e+00
#   -1.08442440e-15 -4.77618723e+00  1.38081792e-16  2.54710110e-15
#   -2.38550535e-01  7.02992077e-16 -9.73044313e-16 -8.00173222e-17
#    1.35949794e-14 -2.38550535e-01  3.29132096e-15 -1.01878984e+00]
#  [-2.41240964e-01  1.07404043e-16 -3.12158883e-18 -8.43584902e-02
#   -3.79693136e+00 -2.12331085e-15  2.24041054e-16 -3.79693136e+00
#    3.30073315e-16 -3.94537968e+00  1.94378344e-15  7.05889298e-17
#    1.00430597e-02  8.63250701e-16 -1.37292548e-15 -1.22127104e-15
#    3.45289467e-15  1.00430597e-02  1.03724149e-15 -1.31736368e-01]]

# %% [markdown]
# ## GISA method

# %%
from horton_part import GaussianISAWPart

def main_gisa():
    mol, grid, rho = prepare_grid_and_dens()
    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GaussianISAWPart(**kwargs)
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_gisa()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.15212468 -0.15225026]
# cartesian multipoles:
# [[ 1.52124677e-01  2.73601984e-16  1.32222322e-15 -2.26375080e-01
#   -4.07392305e+00 -1.34573763e-15  3.02970173e-16 -4.07392305e+00
#   -6.14690321e-16 -5.04346073e+00  4.21993733e-15  1.31125164e-15
#    1.00440469e-01  2.16476488e-15 -8.72436609e-16  3.65015024e-15
#    1.07430830e-14  1.00440469e-01  3.50216150e-16 -3.22249742e-01]
#  [-1.52250262e-01  1.24585071e-17 -2.22322812e-18  8.58694210e-03
#   -3.55113594e+00 -2.02936793e-15  6.37886581e-16 -3.55113594e+00
#   -1.90701726e-16 -3.68859780e+00 -1.97009904e-15  1.22841212e-15
#    1.96373155e-01 -5.57456535e-16 -1.30605495e-15 -2.34614891e-15
#    6.34115127e-15  1.96373155e-01  1.88858275e-15  4.16172812e-01]]

# %% [markdown]
# ## LISA method

# %%
from horton_part import LinearISAWPart

def main_lisa():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = LinearISAWPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 -6.1341e+00  7e+00  1e+00  1e+00
#  1:  1.3115e-02 -1.1385e+00  2e+00  3e-01  4e-01
#  2:  5.4347e-02 -4.2828e-01  5e-01  2e-02  1e-02
#  3:  6.7496e-03 -6.2831e-02  9e-02  1e-02  7e-03
#  4:  3.4753e-03 -1.3899e-02  3e-02  4e-03  3e-03
#  5:  4.1595e-03  1.5886e-03  5e-03  8e-04  7e-04
#  6:  4.6201e-03  4.2298e-03  7e-04  1e-04  9e-05
#  7:  4.5316e-03  4.4480e-03  2e-04  3e-05  2e-05
#  8:  4.4898e-03  4.4750e-03  3e-05  5e-06  4e-06
#  9:  4.4783e-03  4.4771e-03  2e-06  5e-07  3e-07
# 10:  4.4771e-03  4.4771e-03  4e-08  9e-09  7e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 -7.8428e+00  7e+00  1e+00  1e+00
#  1:  8.6157e-02 -1.3020e+00  3e+00  5e-01  5e-01
#  2:  1.0075e-01 -6.1060e-01  8e-01  2e-02  8e-03
#  3: -1.1627e-02 -1.6153e-01  2e-01  1e-02  1e-02
#  4: -4.4924e-03 -2.2685e-02  3e-02  3e-03  4e-03
#  5:  2.1326e-03 -4.8394e-04  4e-03  5e-04  7e-04
#  6:  3.3405e-03  3.1861e-03  3e-04  3e-05  5e-05
#  7:  3.4338e-03  3.4314e-03  4e-06  5e-07  9e-07
#  8:  3.4353e-03  3.4352e-03  4e-08  5e-09  9e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 -5.8884e+00  7e+00  1e+00  1e+00
#  1:  1.6442e-02 -1.1194e+00  2e+00  3e-01  3e-01
#  2:  5.3665e-02 -4.2619e-01  5e-01  2e-02  1e-02
#  3:  5.8235e-03 -6.3682e-02  9e-02  1e-02  7e-03
#  4:  2.5462e-03 -1.4761e-02  3e-02  3e-03  3e-03
#  5:  3.2770e-03  7.1837e-04  4e-03  8e-04  7e-04
#  6:  3.7570e-03  3.3662e-03  7e-04  1e-04  9e-05
#  7:  3.6788e-03  3.5933e-03  2e-04  3e-05  2e-05
#  8:  3.6404e-03  3.6241e-03  3e-05  6e-06  4e-06
#  9:  3.6286e-03  3.6270e-03  3e-06  6e-07  5e-07
# 10:  3.6271e-03  3.6270e-03  8e-08  2e-08  1e-08
# 11:  3.6270e-03  3.6270e-03  8e-10  2e-10  1e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 
2e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 -8.1954e+00  7e+00  1e+00  1e+00
#  1:  2.5351e-02 -1.3967e+00  3e+00  5e-01  6e-01
#  2:  1.2715e-01 -6.2951e-01  8e-01  1e-02  7e-03
#  3: -4.2995e-03 -1.7116e-01  2e-01  1e-02  9e-03
#  4: -5.4927e-03 -2.6612e-02  3e-02  3e-03  5e-03
#  5:  1.8730e-03 -1.3000e-03  5e-03  5e-04  8e-04
#  6:  3.2979e-03  3.1029e-03  3e-04  4e-05  6e-05
#  7:  3.4116e-03  3.4087e-03  5e-06  6e-07  1e-06
#  8:  3.4135e-03  3.4135e-03  5e-08  6e-09  1e-08
#  9:  3.4135e-03  3.4135e-03  5e-10  6e-11  1e-10
# Optimal solution found.
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.19866358 -0.198812  ]
# cartesian multipoles:
# [[ 1.98663577e-01  1.58489990e-16  1.25475187e-15 -2.97190104e-01
#   -3.89265121e+00 -1.50683595e-15  5.32674087e-16 -3.89265121e+00
#   -6.48658043e-16 -4.80709457e+00  4.45925094e-15  1.15375773e-15
#   -1.86758414e-01  2.02001176e-15 -2.16842384e-16  3.10321228e-15
#    9.29384489e-15 -1.86758414e-01  6.76497119e-16 -1.00123027e+00]
#  [-1.98812004e-01  7.14309133e-17  3.00874810e-17 -2.00674784e-02
#   -3.73241113e+00 -1.88795400e-15  6.21191179e-16 -3.73241113e+00
#   -3.33568202e-17 -3.83485151e+00 -1.81787719e-15  1.51304695e-15
#    9.61444370e-02 -4.51689089e-16 -1.63674369e-15 -2.22139915e-15
#    7.72627265e-15  9.61444370e-02  1.93908395e-15  9.56839980e-02]]

# %% [markdown]
# ## Global LISA-101

# %%
from horton_part.lisa_g import GlobalLinearISA101WPart

def main_lisa_g_101():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA101WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])
    
main_lisa_g_101()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00 -1.3888e+01  1e+01  1e+00  1e+00
#  1:  1.5544e-01 -2.9659e+00  5e+00  5e-01  5e-01
#  2:  2.5074e-01 -1.2986e+00  2e+00  9e-02  9e-02
#  3:  9.3163e-02 -3.3206e-01  5e-01  3e-02  2e-02
#  4:  8.2543e-02  5.1641e-03  1e-01  8e-03  6e-03
#  5:  8.8954e-02  7.6087e-02  2e-02  2e-03  2e-03
#  6:  9.2165e-02  9.0777e-02  2e-03  3e-04  2e-04
#  7:  9.2405e-02  9.2198e-02  4e-04  5e-05  3e-05
#  8:  9.2352e-02  9.2307e-02  8e-05  1e-05  8e-06
#  9:  9.2329e-02  9.2322e-02  1e-05  2e-06  1e-06
# 10:  9.2323e-02  9.2323e-02  1e-06  1e-07  1e-07
# 11:  9.2323e-02  9.2323e-02  2e-08  2e-09  2e-09
# Optimal solution found.
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.198679   -0.19882739]
# cartesian multipoles:
# [[ 1.98678996e-01  1.73752421e-16  1.23277204e-15 -2.97216791e-01
#   -3.89260072e+00 -1.48063448e-15  5.32478854e-16 -3.89260072e+00
#   -6.36480344e-16 -4.80701449e+00  4.43623912e-15  1.09129764e-15
#   -1.86828933e-01  2.06832511e-15 -1.66675594e-16  3.04895039e-15
#    9.35136957e-15 -1.86828933e-01  7.11830231e-16 -1.00143016e+00]
#  [-1.98827391e-01  7.13573712e-17  6.39571557e-17 -2.00737387e-02
#   -3.73246162e+00 -1.88648990e-15  6.38941850e-16 -3.73246162e+00
#   -1.15468757e-17 -3.83488794e+00 -2.04557052e-15  1.48755165e-15
#    9.61070472e-02 -4.54738358e-16 -1.64587251e-15 -2.20111705e-15
#    7.87449536e-15  9.61070472e-02  1.95951523e-15  9.55856469e-02]]

# %%
from horton_part.lisa_g import GlobalLinearISA104WPart

def main_lisa_g_104():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA104WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa_g_104()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
#      pcost       dcost       gap    pres   dres
#  0:  0.0000e+00  1.1154e-01  1e+00  1e+00  1e+00
#  1:  6.8539e-02  9.3075e-02  1e-02  3e-02  2e-02
#  2:  9.1305e-02  9.2264e-02  1e-04  1e-03  9e-04
#  3:  9.2238e-02  9.2255e-02  1e-06  2e-05  2e-05
#  4:  9.2255e-02  9.2255e-02  1e-08  2e-07  2e-07
# Optimal solution found.
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.19805266 -0.1982036 ]
# cartesian multipoles:
# [[ 1.98052662e-01  1.68416749e-16  1.28051185e-15 -2.96693323e-01
#   -3.89205580e+00 -1.50446812e-15  5.42176258e-16 -3.89205580e+00
#   -6.47461215e-16 -4.80652631e+00  4.26322402e-15  1.12960853e-15
#   -1.88298788e-01  2.05777672e-15 -1.93588316e-16  3.09419624e-15
#    9.33199931e-15 -1.88298788e-01  7.47849860e-16 -1.00531910e+00]
#  [-1.98203597e-01  3.42851461e-18  9.72763746e-17 -1.92617361e-02
#   -3.73300629e+00 -1.88212991e-15  6.34611039e-16 -3.73300629e+00
#   -1.04997897e-17 -3.83475542e+00 -2.00374521e-15  1.52728377e-15
#    9.64127841e-02 -4.77932607e-16 -1.62557433e-15 -2.24068905e-15
#    7.80076942e-15  9.64127841e-02  1.91442622e-15  9.52882692e-02]]
# /Users/yingxing/Projects/horton-part/src/horton_part/utils.py:523: UserWarning: Not all pro-atom parameters are positive!
#   warnings.warn("Not all pro-atom parameters are positive!")

# %%
from horton_part.lisa_g import GlobalLinearISA301WPart

def main_lisa_g_301():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA301WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa_g_301()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |barrier param|CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------------|-------|
# |   1   |   1   |   0   | +1.1150e-01 | 1.00e+00 | 5.28e-02 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   0   |
# |   2   |   2   |   2   | +1.5542e-01 | 6.03e+00 | 6.83e-02 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   4   |
# |   3   |   3   |   4   | +1.6787e-01 | 1.27e+01 | 2.30e-02 | 0.00e+00 | 1.00e+00 |  1.00e-01   |   4   |
# |   4   |   3   |   4   | +1.6787e-01 | 6.35e+01 | 6.25e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   0   |
# |   5   |   4   |   7   | +1.2463e-01 | 6.35e+01 | 3.49e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |   6   |   5   |  10   | +1.0803e-01 | 6.35e+01 | 1.48e-02 | 0.00e+00 | 1.00e+00 |  2.00e-02   |   4   |
# |   7   |   5   |  10   | +1.0803e-01 | 3.17e+02 | 1.84e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   0   |
# |   8   |   6   |  12   | +1.0803e-01 | 3.17e+01 | 1.84e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |   9   |   7   |  14   | +1.0416e-01 | 3.17e+01 | 1.11e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  10   |   9   |  21   | +1.0416e-01 | 3.17e+00 | 1.11e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  11   |  11   |  24   | +1.0416e-01 | 5.44e-01 | 1.11e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  12   |  12   |  27   | +1.0194e-01 | 5.44e-01 | 1.33e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  13   |  14   |  29   | +1.0194e-01 | 2.72e-01 | 1.33e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  14   |  15   |  32   | +9.8408e-02 | 5.44e-01 | 1.19e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# |  15   |  17   |  35   | +9.8408e-02 | 2.64e-01 | 1.19e-02 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  16   |  18   |  39   | +9.8006e-02 | 5.96e-01 | 8.91e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  17   |  19   |  42   | +9.7709e-02 | 5.96e-01 | 6.66e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  18   |  21   |  46   | +9.7709e-02 | 1.14e-01 | 6.66e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   3   |
# |  19   |  22   |  52   | +9.7053e-02 | 7.97e-01 | 5.41e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# /Users/yingxing/Packages/mambaforge/envs/isa-env/lib/python3.10/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# |  20   |  24   |  60   | +9.7053e-02 | 1.68e-01 | 5.41e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   2   |
# |  21   |  25   |  61   | +9.6900e-02 | 1.68e-01 | 5.07e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  22   |  26   |  68   | +9.6251e-02 | 9.84e-01 | 4.48e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  23   |  27   |  72   | +9.5885e-02 | 9.84e-01 | 5.83e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  24   |  29   |  80   | +9.5885e-02 | 1.92e-01 | 5.83e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  25   |  30   |  86   | +9.5104e-02 | 1.12e+00 | 2.79e-03 | 0.00e+00 | 1.00e+00 |  4.00e-03   |   4   |
# |  26   |  30   |  86   | +9.5104e-02 | 5.62e+00 | 3.81e-03 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   0   |
# |  27   |  31   |  93   | +9.3769e-02 | 5.62e+00 | 2.54e-03 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   4   |
# |  28   |  32   |  102  | +9.3259e-02 | 5.62e+00 | 2.10e-03 | 0.00e+00 | 1.00e+00 |  8.00e-04   |   4   |
# |
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA302WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa_g_302()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------|
# |   1   |   1   |   0   | +1.1150e-01 | 1.00e+00 | 5.41e-02 | 5.60e-05 | 1.00e+00 |   0   |
# |   2   |   2   |   1   | +1.0376e-01 | 1.00e+00 | 3.89e-02 | 0.00e+00 | 1.00e+00 |   4   |
# |   3   |   4   |   3   | +1.0376e-01 | 1.73e-01 | 3.89e-02 | 0.00e+00 | 1.00e+00 |   2   |
# |   4   |   5   |   5   | +9.5693e-02 | 1.21e+00 | 1.85e-02 | 0.00e+00 | 1.00e+00 |   2   |
# |   5   |   6   |   8   | +9.4024e-02 | 1.21e+00 | 1.26e-02 | 1.78e-15 | 1.00e+00 |   4   |
# |   6   |   7   |  10   | +9.3873e-02 | 1.21e+00 | 1.11e-02 | 0.00e+00 | 1.00e+00 |   4   |
# |   7   |   8   |  14   | +9.3873e-02 | 1.37e-01 | 1.11e-02 | 0.00e+00 | 1.00e+00 |   4   |
# |   8   |   9   |  17   | +9.2874e-02 | 9.58e-01 | 8.12e-03 | 1.78e-15 | 1.00e+00 |   2   |
# |   9   |  10   |  21   | +9.2637e-02 | 9.58e-01 | 4.53e-03 | 0.00e+00 | 1.00e+00 |   4   |
# |  10   |  12   |  24   | +9.2637e-02 | 2.66e-01 | 4.53e-03 | 0.00e+00 | 1.00e+00 |   3   |
# |  11   |  13   |  26   | +9.2637e-02 | 9.99e-02 | 4.53e-03 | 0.00e+00 | 1.00e+00 |   3   |
# |  12   |  15   |  28   | +9.2637e-02 | 3.74e-02 | 4.53e-03 | 0.00e+00 | 1.00e+00 |   3   |
# |  13   |  16   |  30   | +9.2514e-02 | 7.48e-02 | 4.72e-03 | 1.78e-15 | 1.00e+00 |   2   |
# |  14   |  18   |  33   | +9.2514e-02 | 3.74e-02 | 4.72e-03 | 1.78e-15 | 1.00e+00 |   3   |
# |  15   |  19   |  38   | +9.2366e-02 | 2.62e-01 | 1.70e-03 | 0.00e+00 | 1.00e+00 |   2   |
# |  16   |  20   |  41   | +9.2366e-02 | 4.73e-02 | 1.70e-03 | 0.00e+00 | 1.00e+00 |   3   |
# |  17   |  21   |  46   | +9.2303e-02 | 2.89e-01 | 1.63e-03 | 0.00e+00 | 1.00e+00 |   4   |
# |  18   |  22   |  47   | +9.2303e-02 | 1.26e-01 | 1.63e-03 | 0.00e+00 | 1.00e+00 |   3   |
# |  19   |  23   |  53   | +9.2271e-02 | 2.13e-01 | 1.30e-03 | 0.00e+00 | 1.00e+00 |   4   |
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.19804868 -0.19819963]
# cartesian multipoles:
# [[ 1.98048679e-01  1.51986942e-16  1.25905822e-15 -2.96691538e-01
#   -3.89204753e+00 -1.49433264e-15  5.52802803e-16 -3.89204753e+00
#   -6.52813671e-16 -4.80651743e+00  4.30497189e-15  1.15273648e-15
#   -1.88312566e-01  2.02462257e-15 -1.94199233e-16  3.12816104e-15
#    9.44285775e-15 -1.88312566e-01  7.12404271e-16 -1.00535402e+00]
#  [-1.98199630e-01 -3.40134849e-18  3.30000702e-17 -1.92550175e-02
#   -3.73301455e+00 -1.89393735e-15  6.12551270e-16 -3.73301455e+00
#   -2.37984299e-17 -3.83475374e+00 -1.93063273e-15  1.50056443e-15
#    9.64089025e-02 -4.11047333e-16 -1.63720183e-15 -2.19053071e-15
#    7.69703801e-15  9.64089025e-02  1.97043376e-15  9.52806858e-02]]

# %%
from horton_part.lisa_g import GlobalLinearISA201WPart

def main_lisa_g_201():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA201WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa_g_201()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# Computing atomic populations.
# Computing atomic charges.
# Computing density decomposition for atom 0
# Computing density decomposition for atom 1
# Computing cartesian and pure AIM multipoles and radial AIM moments.
# charges:
# [ 0.19868617 -0.19883453]
# cartesian multipoles:
# [[ 1.98686167e-01  1.67003570e-16  1.21726466e-15 -2.97222544e-01
#   -3.89260795e+00 -1.51471977e-15  5.51612747e-16 -3.89260795e+00
#   -6.28187046e-16 -4.80702148e+00  4.26529444e-15  1.15399679e-15
#   -1.86810377e-01  1.96395376e-15 -1.72195218e-16  3.06901742e-15
#    9.33290171e-15 -1.86810377e-01  7.15989598e-16 -1.00138101e+00]
#  [-1.98834532e-01 -1.42079735e-17  5.84177761e-17 -2.00832750e-02
#   -3.73245439e+00 -1.89510281e-15  6.42252842e-16 -3.73245439e+00
#    7.04078051e-18 -3.83488908e+00 -1.96089807e-15  1.46355151e-15
#    9.61039435e-02 -4.39794972e-16 -1.64844899e-15 -2.19945671e-15
#    7.77081278e-15  9.61039435e-02  1.94264433e-15  9.55901161e-02]]

# %%
from horton_part.lisa_g import GlobalLinearISA206WPart

def main_lisa_g_206():
    mol, grid, rho = prepare_grid_and_dens()

    kwargs = {
        "coordinates": mol.atcoords,
        "numbers": mol.atnums,
        "pseudo_numbers": mol.atnums,
        "grid": grid,
        "moldens": rho,
        "lmax": 3,
        "maxiter": 1000,
        "solver": 1,
    }

    part = GlobalLinearISA206WPart(**kwargs)
    # part.do_partitioning()
    part.do_all()

    print("charges:")
    print(part.cache["charges"])
    print("cartesian multipoles:")
    print(part.cache["cartesian_multipoles"])

main_lisa_g_206()
# Out:
# The number of electrons: 13.999981376822717
# Coordinates of the atoms
#  [[0.         0.         2.13728025]
#  [0.         0.         0.        ]]
# Atomic numbers of the atom
#  [6 8]
# /Users/yingxing/Projects/horton-part/src/horton_part/lisa_g.py:563: UserWarning: Negative parameters found!
#   warnings.warn("Negative parameters found!")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 26
#      23     print("cartesian multipoles:")
#      24     print(part.cache["cartesian_multipoles"])
# ---> 26 main_lisa_g_206()
#
# Cell In[3], line 19, in main_lisa_g_206()
#      17 part = GlobalLinearISA206WPart(**kwargs)
#      18 # part.do_partitioning()
# ---> 19 part.do_all()
#      21 print("charges:")
#      22 print(part.cache["charges"])
#
# File ~/Projects/horton-part/src/horton_part/core/base.py:328, in Part.do_all(self)
#     326     attr = getattr(self, attr_name)
#     327     if callable(attr) and attr_name.startswith("do_") and attr_name != "do_all":
# --> 328         attr()
#     329 return list(self.cache.iterkeys(tags="o"))
#
# File ~/Projects/horton-part/src/horton_part/core/cache.py:75, in just_once.<locals>.wrapper(instance)
#      73     return
#      74 t0 = time.time()
# ---> 75 fn(instance)
#      76 t1 = time.time()
#      77 instance._done_just_once.add(fn.__name__)
#
# File ~/Projects/horton-part/src/horton_part/core/base.py:234, in Part.do_charges(self)
#     232 charges, new = self._cache.load("charges", alloc=self.natom, tags="o")
#     233 if new:
# --> 234     self.do_populations()
#     235     populations = self._cache.load("populations")
#     236     print("Computing atomic charges.")
#
# File ~/Projects/horton-part/src/horton_part/core/cache.py:75, in just_once.<locals>.wrapper(instance)
#      73     return
#      74 t0 = time.time()
# ---> 75 fn(instance)
#      76 t1 = time.time()
#      77 instance._done_just_once.add(fn.__name__)
#
# File ~/Projects/horton-part/src/horton_part/core/base.py:220, in Part.do_populations(self)
#     218 populations, new = self.cache.load("populations", alloc=self.natom, tags="o")
#     219 if new:
# --> 220     self.do_partitioning()
#     221     pseudo_populations = self.cache.load(
#     222         "pseudo_populations", alloc=self.natom, tags="o"
#     223     )[0]
#     224     print("Computing atomic populations.")
#
# File ~/Projects/horton-part/src/horton_part/core/cache.py:75, in just_once.<locals>.wrapper(instance)
#      73     return
#      74 t0 = time.time()
# ---> 75 fn(instance)
#      76 t1 = time.time()
#      77 instance._done_just_once.add(fn.__name__)
#
# File ~/Projects/horton-part/src/horton_part/lisa_g.py:107, in AbstractGlobalLinearISAWPart.do_partitioning(self)
#     105 self._init_propars()
#     106 t0 = time.time()
# --> 107 new_propars = self._opt_propars()
#     108 t1 = time.time()
#     109 logger.info(f"Time usage for partitioning: {t1-t0:.2f} s")
#
# File ~/Projects/horton-part/src/horton_part/lisa_g.py:565, in GlobalLinearISA206WPart._opt_propars(self)
#     562     if not np.all(all_propars >= -1e-10).all():
#     563         warnings.warn("Negative parameters found!")
# --> 565 raise RuntimeError("Error: inner iteration is not converge!")
#
# RuntimeError: Error: inner iteration is not converge!
